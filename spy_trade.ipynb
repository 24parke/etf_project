# %%
import backtrader as bt
import yfinance as yf
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
class Summary:
    def __init__(self, underlying, triple):
        self.UNDERLYING = underlying
        self.TRIPLE = triple
        self.STARTING_VALUE_UNDER = 3000
        self.STARTING_VALUE_TRIP = -1000
        self.TICKERS = [underlying, triple]

        self.data = yf.download(self.TICKERS, period="8y", group_by="ticker", auto_adjust=False)
        self.dat_under = self.data[underlying]['Close']
        self.dat_trip = self.data[triple]['Close']

        self.shares_under = self.STARTING_VALUE_UNDER / self.dat_under[0]
        self.shares_trip = self.STARTING_VALUE_TRIP / self.dat_trip[0]
        dates = [d.strftime('%Y-%m-%d') for d in self.data.index.date]
        self.dfr = pd.DataFrame(data = {f"{underlying}_Close": self.dat_under})
        self.dfr.index = dates
        self.dfr[f"{underlying}_per_change"] = 1
        self.dfr[f"{underlying}_cumulative"] = 1
        self.dfr[f"{triple}_Close"] = self.dat_trip
        self.dfr[f"{triple}_per_change"] = 1
        self.dfr[f"{triple}_cumulative"] = 1
        self.dfr[f"ideal_per_change"] = 1
        self.dfr[f"ideal_cumulative"] = 1


    def summary_stats(self):
        for i in range(1, len(self.dat_under)):
            self.dfr[f"{self.UNDERLYING}_per_change"][i] = self.dat_under[i] / self.dat_under[i-1] - 1
            self.dfr[f"{self.TRIPLE}_per_change"][i] = self.dat_trip[i] / self.dat_trip[i-1] - 1
            self.dfr["ideal_per_change"][i] = (self.dat_under[i] / self.dat_under[i-1] - 1) *3

            self.dfr[f"{self.UNDERLYING}_cumulative"][i] = self.dfr[f"{self.UNDERLYING}_cumulative"][i-1]*(1 + self.dfr[f"{self.UNDERLYING}_per_change"][i])
            self.dfr[f"{self.TRIPLE}_cumulative"][i] = self.dfr[f"{self.TRIPLE}_cumulative"][i-1]*(1 + self.dfr[f"{self.TRIPLE}_per_change"][i])
            self.dfr["ideal_cumulative"][i] = self.dfr["ideal_cumulative"][i-1]*(1 + self.dfr["ideal_per_change"][i])


    def calc_returns(self):
        quart_under = self.data[self.UNDERLYING]['Adj Close'].resample('ME').last().pct_change()*3
        quart_trip = self.data[self.TRIPLE]['Adj Close'].resample('ME').last().pct_change()
        plt.plot(quart_under, label = f"{self.UNDERLYING} quarterly returns, beta adjusted", linewidth=0.85)
        plt.plot(quart_trip, label = f"{self.TRIPLE} quarterly returns", linewidth = 0.85)
        plt.legend()
        plt.grid(True)
        plt.show()
        quart_under = round(quart_under, 3)
        quart_trip = round(quart_trip, 3)

        d = pd.DataFrame(data = {(f"{self.UNDERLYING} quarterly returns (%)"): quart_under, f"{self.TRIPLE} quarterly returns (%)": quart_trip})
    
    
    def init_portfolio(self):
        self.dfr[f"portfolio_{self.UNDERLYING}_long"]= 1
        self.dfr[f"portfolio_{self.TRIPLE}_short"]= 0
        self.dfr["portfolio_total"]=0
        self.dfr["beta_exposure"]=0


    def calc_portfolio(self, i):      
        self.dfr[f"portfolio_{self.UNDERLYING}_long"][i] = self.shares_under * self.dfr[f"{self.UNDERLYING}_Close"][i]
        self.dfr[f"portfolio_{self.TRIPLE}_short"][i] = self.shares_trip * self.dfr[f"{self.TRIPLE}_Close"][i]
        self.dfr["portfolio_total"][i] = self.dfr[f"portfolio_{self.UNDERLYING}_long"][i] + self.dfr[f"portfolio_{self.TRIPLE}_short"][i]
        self.dfr["beta_exposure"][i] = (self.shares_under * self.dfr[f"{self.UNDERLYING}_Close"][i]) + (self.shares_trip * self.dfr[f"{self.TRIPLE}_Close"][i] * 3)
        #num shares * share price * -3 + num shares * share price
        

    def plot_portfolio(self):
        self.dfr = round(self.dfr, 2)
        self.dfr.to_csv('new.csv')
        plt.plot(self.dfr[f"portfolio_{self.UNDERLYING}_long"], label = f"portfolio_{self.UNDERLYING}_long", linewidth=0.85)
        plt.plot(self.dfr[f"portfolio_{self.TRIPLE}_short"], label = f"portfolio_{self.TRIPLE}_short", linewidth=0.85)
        plt.plot(self.dfr['portfolio_total'], label = "portfolio_total", linewidth=0.85)
        plt.plot(self.dfr['beta_exposure'], label = "beta_exposure", linewidth=0.85)
        plt.legend()
        plt.grid(True)
        plt.savefig("new.png")
        plt.show()

    def beta_norm_strategy(self):
        for i in range(1, len(self.dat_under)):
            if (self.dfr['beta_exposure'][i] > 150):
                amt = self.dfr['beta_exposure']/3/self.dfr[f"{self.TRIPLE}_Close"]
                self.shares_trip -= amt
                print(f"selling {amt} shares of SPXL")
            elif (self.dfr['beta_exposure'][i] < -150):
                amt = self.dfr['beta_exposure']/self.dfr[f"{self.UNDERLYING}_Close"]
                self.shares_under += amt
                print(f"buying {amt} shares of SPY")
            self.calc_portfolio(i)

# %%
spy = Summary(underlying="SPY", triple="SPXL")
spy.summary_stats()
spy.calc_returns()
spy.init_portfolio()
spy.beta_norm_strategy()
spy.plot_portfolio()
# Out:
# [*********************100%***********************]  2 of 2 completed
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.shares_under = self.STARTING_VALUE_UNDER / self.dat_under[0]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.shares_trip = self.STARTING_VALUE_TRIP / self.dat_trip[0]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.dfr[f"{self.UNDERLYING}_per_change"][i] = self.dat_under[i] / self.dat_under[i-1] - 1
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:29: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.dfr[f"{self.UNDERLYING}_per_change"][i] = self.dat_under[i] / self.dat_under[i-1] - 1
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.dfr[f"{self.UNDERLYING}_per_change"][i] = self.dat_under[i] / self.dat_under[i-1] - 1
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:29: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.dfr[f"{self.UNDERLYING}_per_change"][i] = self.dat_under[i] / self.dat_under[i-1] - 1
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.005413994183945503' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.dfr[f"{self.UNDERLYING}_per_change"][i] = self.dat_under[i] / self.dat_under[i-1] - 1
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:30: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.dfr[f"{self.TRIPLE}_per_change"][i] = self.dat_trip[i] / self.dat_trip[i-1] - 1
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:30: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.dfr[f"{self.TRIPLE}_per_change"][i] = self.dat_trip[i] / self.dat_trip[i-1] - 1
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.dfr[f"{self.TRIPLE}_per_change"][i] = self.dat_trip[i] / self.dat_trip[i-1] - 1
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:30: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.dfr[f"{self.TRIPLE}_per_change"][i] = self.dat_trip[i] / self.dat_trip[i-1] - 1
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:30: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.016255549646766232' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.dfr[f"{self.TRIPLE}_per_change"][i] = self.dat_trip[i] / self.dat_trip[i-1] - 1
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:31: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.dfr["ideal_per_change"][i] = (self.dat_under[i] / self.dat_under[i-1] - 1) *3
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:31: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.dfr["ideal_per_change"][i] = (self.dat_under[i] / self.dat_under[i-1] - 1) *3
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.dfr["ideal_per_change"][i] = (self.dat_under[i] / self.dat_under[i-1] - 1) *3
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:31: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.dfr["ideal_per_change"][i] = (self.dat_under[i] / self.dat_under[i-1] - 1) *3
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.01624198255183651' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.dfr["ideal_per_change"][i] = (self.dat_under[i] / self.dat_under[i-1] - 1) *3
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.dfr[f"{self.UNDERLYING}_cumulative"][i] = self.dfr[f"{self.UNDERLYING}_cumulative"][i-1]*(1 + self.dfr[f"{self.UNDERLYING}_per_change"][i])
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:33: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.dfr[f"{self.UNDERLYING}_cumulative"][i] = self.dfr[f"{self.UNDERLYING}_cumulative"][i-1]*(1 + self.dfr[f"{self.UNDERLYING}_per_change"][i])
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.dfr[f"{self.UNDERLYING}_cumulative"][i] = self.dfr[f"{self.UNDERLYING}_cumulative"][i-1]*(1 + self.dfr[f"{self.UNDERLYING}_per_change"][i])
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:33: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.dfr[f"{self.UNDERLYING}_cumulative"][i] = self.dfr[f"{self.UNDERLYING}_cumulative"][i-1]*(1 + self.dfr[f"{self.UNDERLYING}_per_change"][i])
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:33: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0054139941839455' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.dfr[f"{self.UNDERLYING}_cumulative"][i] = self.dfr[f"{self.UNDERLYING}_cumulative"][i-1]*(1 + self.dfr[f"{self.UNDERLYING}_per_change"][i])
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.dfr[f"{self.TRIPLE}_cumulative"][i] = self.dfr[f"{self.TRIPLE}_cumulative"][i-1]*(1 + self.dfr[f"{self.TRIPLE}_per_change"][i])
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:34: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.dfr[f"{self.TRIPLE}_cumulative"][i] = self.dfr[f"{self.TRIPLE}_cumulative"][i-1]*(1 + self.dfr[f"{self.TRIPLE}_per_change"][i])
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.dfr[f"{self.TRIPLE}_cumulative"][i] = self.dfr[f"{self.TRIPLE}_cumulative"][i-1]*(1 + self.dfr[f"{self.TRIPLE}_per_change"][i])
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:34: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.dfr[f"{self.TRIPLE}_cumulative"][i] = self.dfr[f"{self.TRIPLE}_cumulative"][i-1]*(1 + self.dfr[f"{self.TRIPLE}_per_change"][i])
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:34: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0162555496467662' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.dfr[f"{self.TRIPLE}_cumulative"][i] = self.dfr[f"{self.TRIPLE}_cumulative"][i-1]*(1 + self.dfr[f"{self.TRIPLE}_per_change"][i])
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:35: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.dfr["ideal_cumulative"][i] = self.dfr["ideal_cumulative"][i-1]*(1 + self.dfr["ideal_per_change"][i])
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:35: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.dfr["ideal_cumulative"][i] = self.dfr["ideal_cumulative"][i-1]*(1 + self.dfr["ideal_per_change"][i])
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.dfr["ideal_cumulative"][i] = self.dfr["ideal_cumulative"][i-1]*(1 + self.dfr["ideal_per_change"][i])
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:35: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.dfr["ideal_cumulative"][i] = self.dfr["ideal_cumulative"][i-1]*(1 + self.dfr["ideal_per_change"][i])
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:35: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0162419825518365' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.dfr["ideal_cumulative"][i] = self.dfr["ideal_cumulative"][i-1]*(1 + self.dfr["ideal_per_change"][i])
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.dfr[f"{self.UNDERLYING}_per_change"][i] = self.dat_under[i] / self.dat_under[i-1] - 1
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:29: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.dfr[f"{self.UNDERLYING}_per_change"][i] = self.dat_under[i] / self.dat_under[i-1] - 1
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:30: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.dfr[f"{self.TRIPLE}_per_change"][i] = self.dat_trip[i] / self.dat_trip[i-1] - 1
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:30: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.dfr[f"{self.TRIPLE}_per_change"][i] = self.dat_trip[i] / self.dat_trip[i-1] - 1
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:31: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.dfr["ideal_per_change"][i] = (self.dat_under[i] / self.dat_under[i-1] - 1) *3
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:31: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.dfr["ideal_per_change"][i] = (self.dat_under[i] / self.dat_under[i-1] - 1) *3
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.dfr[f"{self.UNDERLYING}_cumulative"][i] = self.dfr[f"{self.UNDERLYING}_cumulative"][i-1]*(1 + self.dfr[f"{self.UNDERLYING}_per_change"][i])
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:33: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.dfr[f"{self.UNDERLYING}_cumulative"][i] = self.dfr[f"{self.UNDERLYING}_cumulative"][i-1]*(1 + self.dfr[f"{self.UNDERLYING}_per_change"][i])
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.dfr[f"{self.TRIPLE}_cumulative"][i] = self.dfr[f"{self.TRIPLE}_cumulative"][i-1]*(1 + self.dfr[f"{self.TRIPLE}_per_change"][i])
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:34: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.dfr[f"{self.TRIPLE}_cumulative"][i] = self.dfr[f"{self.TRIPLE}_cumulative"][i-1]*(1 + self.dfr[f"{self.TRIPLE}_per_change"][i])
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:35: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.dfr["ideal_cumulative"][i] = self.dfr["ideal_cumulative"][i-1]*(1 + self.dfr["ideal_per_change"][i])
# <div id='bf4f6eb8-90c8-4709-972b-5914e7a06bfb'></div>
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:81: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (self.dfr['beta_exposure'][i] > 150):
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:85: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif (self.dfr['beta_exposure'][i] < -150):
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:60: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.dfr[f"portfolio_{self.UNDERLYING}_long"][i] = self.shares_under * self.dfr[f"{self.UNDERLYING}_Close"][i]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.dfr[f"portfolio_{self.UNDERLYING}_long"][i] = self.shares_under * self.dfr[f"{self.UNDERLYING}_Close"][i]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.dfr[f"portfolio_{self.UNDERLYING}_long"][i] = self.shares_under * self.dfr[f"{self.UNDERLYING}_Close"][i]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:60: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.dfr[f"portfolio_{self.UNDERLYING}_long"][i] = self.shares_under * self.dfr[f"{self.UNDERLYING}_Close"][i]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:60: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3016.2419825518364' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.dfr[f"portfolio_{self.UNDERLYING}_long"][i] = self.shares_under * self.dfr[f"{self.UNDERLYING}_Close"][i]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:61: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.dfr[f"portfolio_{self.TRIPLE}_short"][i] = self.shares_trip * self.dfr[f"{self.TRIPLE}_Close"][i]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:61: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.dfr[f"portfolio_{self.TRIPLE}_short"][i] = self.shares_trip * self.dfr[f"{self.TRIPLE}_Close"][i]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.dfr[f"portfolio_{self.TRIPLE}_short"][i] = self.shares_trip * self.dfr[f"{self.TRIPLE}_Close"][i]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:61: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.dfr[f"portfolio_{self.TRIPLE}_short"][i] = self.shares_trip * self.dfr[f"{self.TRIPLE}_Close"][i]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:61: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-1016.2555496467662' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.dfr[f"portfolio_{self.TRIPLE}_short"][i] = self.shares_trip * self.dfr[f"{self.TRIPLE}_Close"][i]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:62: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.dfr["portfolio_total"][i] = self.dfr[f"portfolio_{self.UNDERLYING}_long"][i] + self.dfr[f"portfolio_{self.TRIPLE}_short"][i]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.dfr["portfolio_total"][i] = self.dfr[f"portfolio_{self.UNDERLYING}_long"][i] + self.dfr[f"portfolio_{self.TRIPLE}_short"][i]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.dfr["portfolio_total"][i] = self.dfr[f"portfolio_{self.UNDERLYING}_long"][i] + self.dfr[f"portfolio_{self.TRIPLE}_short"][i]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:62: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.dfr["portfolio_total"][i] = self.dfr[f"portfolio_{self.UNDERLYING}_long"][i] + self.dfr[f"portfolio_{self.TRIPLE}_short"][i]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:62: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1999.9864329050702' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.dfr["portfolio_total"][i] = self.dfr[f"portfolio_{self.UNDERLYING}_long"][i] + self.dfr[f"portfolio_{self.TRIPLE}_short"][i]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:63: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.dfr["beta_exposure"][i] = (self.shares_under * self.dfr[f"{self.UNDERLYING}_Close"][i]) + (self.shares_trip * self.dfr[f"{self.TRIPLE}_Close"][i] * 3)
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:63: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.dfr["beta_exposure"][i] = (self.shares_under * self.dfr[f"{self.UNDERLYING}_Close"][i]) + (self.shares_trip * self.dfr[f"{self.TRIPLE}_Close"][i] * 3)
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.dfr["beta_exposure"][i] = (self.shares_under * self.dfr[f"{self.UNDERLYING}_Close"][i]) + (self.shares_trip * self.dfr[f"{self.TRIPLE}_Close"][i] * 3)
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:63: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.dfr["beta_exposure"][i] = (self.shares_under * self.dfr[f"{self.UNDERLYING}_Close"][i]) + (self.shares_trip * self.dfr[f"{self.TRIPLE}_Close"][i] * 3)
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:63: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-32.524666388462265' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.dfr["beta_exposure"][i] = (self.shares_under * self.dfr[f"{self.UNDERLYING}_Close"][i]) + (self.shares_trip * self.dfr[f"{self.TRIPLE}_Close"][i] * 3)
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:81: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (self.dfr['beta_exposure'][i] > 150):
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:85: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif (self.dfr['beta_exposure'][i] < -150):
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:60: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.dfr[f"portfolio_{self.UNDERLYING}_long"][i] = self.shares_under * self.dfr[f"{self.UNDERLYING}_Close"][i]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:60: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.dfr[f"portfolio_{self.UNDERLYING}_long"][i] = self.shares_under * self.dfr[f"{self.UNDERLYING}_Close"][i]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:61: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.dfr[f"portfolio_{self.TRIPLE}_short"][i] = self.shares_trip * self.dfr[f"{self.TRIPLE}_Close"][i]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:61: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.dfr[f"portfolio_{self.TRIPLE}_short"][i] = self.shares_trip * self.dfr[f"{self.TRIPLE}_Close"][i]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:62: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.dfr["portfolio_total"][i] = self.dfr[f"portfolio_{self.UNDERLYING}_long"][i] + self.dfr[f"portfolio_{self.TRIPLE}_short"][i]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:62: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.dfr["portfolio_total"][i] = self.dfr[f"portfolio_{self.UNDERLYING}_long"][i] + self.dfr[f"portfolio_{self.TRIPLE}_short"][i]
# /var/folders/l9/9g52f8pd74xdlydy3kyw4rhc0000gn/T/ipykernel_3754/2942721935.py:63: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.dfr["beta_exposure"][i] = (self.shares_under * self.dfr[f"{self.UNDERLYING}_Close"][i]) + (self.shares_trip * self.dfr[f"{self.TRIPLE}_Close"][i] * 3)
# <div id='02e983c2-f789-479f-9920-9bf9b40aad42'></div>

# %%
# -----------------------------
# Step 1: Download data
# -----------------------------

csv_file_path = 'spy.csv'
df = pd.read_csv(csv_file_path, index_col=0, parse_dates = True)

spy_df = df["SPY_Close"]
spxl_df = df["SPXL_Close"]

spy_df.to_csv("test.csv")
# beta_df = pd.read_csv("beta.csv", index_col=0, parse_dates=True)

spy_df = pd.DataFrame()
spy_df["Open"] = df["SPY_Close"]
spy_df["High"] = df["SPY_Close"]
spy_df["Low"] = df["SPY_Close"]
spy_df["Close"] = df["SPY_Close"]
spy_df["Volume"] = 1  # or use real volume if available

# Optional: set datetime index
# spy_df["Date"] = pd.to_datetime(df["Date"])
# spy_df.set_index("Date", inplace=True)


spxl_df = pd.DataFrame()
spxl_df["Open"] = df["SPXL_Close"]
spxl_df["High"] = df["SPXL_Close"]
spxl_df["Low"] = df["SPXL_Close"]
spxl_df["Close"] = df["SPXL_Close"]
spxl_df["Volume"] = 1


# spxl_df["Date"] = pd.to_datetime(df["Date"])
# spxl_df.set_index("Date", inplace=True)

# Align dates and calculate dummy beta exposure (replace with your own logic)

# Backtrader expects OHLCV columns — fill in dummy values if needed
# for col in ['Open', 'High', 'Low', 'Volume']:
#     df[col] = df['Close']
# df = df[['Open', 'High', 'Low', 'Close', 'Volume', 'beta_exposure']]

# -----------------------------
# Step 2: Custom Data Feed
# -----------------------------

# class BetaExposureFeed(bt.feeds.PandasData):
#     lines = ('beta_exposure',)
#     params = (('beta_exposure', 0),)

# -----------------------------
# Step 3: Strategy
# -----------------------------

class BetaNeutralStrategy(bt.Strategy):
    def __init__(self):
        self.spy = self.datas[0]  # SPY
        self.spxl = self.datas[1]  # SPXL
        # self.beta_series = self.datas[2]

        self.spy_beta = 1.0
        self.spxl_beta = 3.0
        self.has_bought = False
    def next(self):
        # beta_now = self.beta_series[0]
        # cash = self.broker.get_cash()
        # df = self.spy.datetime.date

        if not self.has_bought:
            a = 3000/245.52999877929700
            b = 1000/35.619998931884800
            self.buy(data=self.datas[0], size = a)
            self.sell(data=self.datas[1], size = b)
            self.has_bought = True
            print(f"{self.datas[0].datetime.date(0)} | Buying {a} shares of {self.datas[0]._name}")
            print(f"{self.datas[1].datetime.date(0)} | Selling {b} shares of {self.datas[0]._name}")

        spy_pos = self.getposition(self.datas[0]).size
        spxl_pos = self.getposition(self.datas[1]).size

        # spy_pos = self.getposition(self.spy).size
        # spxl_pos = self.getposition(self.spxl).size

        # beta_now = (spxl_pos*self.spxl[0]) * -3 + (spy_pos*self.spy[0])

        beta_now = abs((spxl_pos * self.datas[1])) * -3 + spy_pos
        



        cash = self.broker.get_cash()
        dt = self.spy.datetime.date(0)
        print(f"{dt} | Beta Exposure: {beta_now:.2f} | Cash: {cash:.2f}")

        # Get current positions

        # Calculate current beta exposure from positions
        # portfolio_beta = spy_pos * self.spy_beta + spxl_pos * -self.spxl_beta
        # print(f"Current Portfolio Beta: {portfolio_beta:.2f} | SPY: {spy_pos}, SPXL: {spxl_pos}")
        print(f"SPY: {spy_pos}, SPXL: {spxl_pos}")


        if beta_now > 1000:
            # We are too long, increase short SPXL
            spxl_price = self.spxl.close[0]
            needed_beta = -beta_now
            shares = round(needed_beta / self.spxl_beta / spxl_price)
            print(f"→ Selling short {shares} SPXL to reduce beta")
            self.sell(data=self.spxl, size=shares)

        elif beta_now < -1000:
            # We are too short, increase long SPY
            spy_price = self.spy.close[0]
            needed_beta = -beta_now
            shares = round(needed_beta / self.spy_beta / spy_price)
            print(f"→ Buying {shares} SPY to reduce beta")
            self.buy(data=self.spy, size=shares)

# -----------------------------
# Step 4: Setup and Run Cerebro
# -----------------------------

cerebro = bt.Cerebro()
cerebro.broker.set_cash(100000)
cerebro.addstrategy(BetaNeutralStrategy)

# Add SPY and SPXL price data
spy_feed = bt.feeds.PandasData(dataname=spy_df)
spxl_feed = bt.feeds.PandasData(dataname=spxl_df)
# beta_feed = BetaExposureFeed(dataname=beta_df)

cerebro.adddata(spy_feed)   # datas[0]
cerebro.adddata(spxl_feed)  # datas[1]
# cerebro.adddata(beta_feed)  # datas[2]


results = cerebro.run()
figs = cerebro.plot(style='candlestick')[0]
figures = cerebro.plot()
fig = figs[0]  # grab the first figure

fig.savefig("backtrader_plot.png", dpi=300, bbox_inches='tight')
# Out:
# 2017-07-17 | Buying 12.21846623595943 shares of
# 2017-07-17 | Selling 28.07411650719794 shares of
# 2017-07-17 | Beta Exposure: 0.00 | Cash: 100000.00
# SPY: 0, SPXL: 0
# 2017-07-18 | Beta Exposure: -2992.83 | Cash: 98000.10
# SPY: 12.21846623595943, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-07-19 | Beta Exposure: -3029.68 | Cash: 95036.22
# SPY: 24.21846623595943, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-07-20 | Beta Exposure: -3020.21 | Cash: 92071.02
# SPY: 36.218466235959426, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-07-21 | Beta Exposure: -3002.32 | Cash: 89108.46
# SPY: 48.218466235959426, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-07-24 | Beta Exposure: -2986.10 | Cash: 86146.62
# SPY: 60.218466235959426, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-07-25 | Beta Exposure: -2996.84 | Cash: 83177.58
# SPY: 72.21846623595943, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-07-26 | Beta Exposure: -2984.84 | Cash: 80208.42
# SPY: 84.21846623595943, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-07-27 | Beta Exposure: -2964.42 | Cash: 77242.02
# SPY: 96.21846623595943, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-07-28 | Beta Exposure: -2939.79 | Cash: 74279.10
# SPY: 108.21846623595943, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-07-31 | Beta Exposure: -2922.74 | Cash: 71317.86
# SPY: 120.21846623595943, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-08-01 | Beta Exposure: -2929.26 | Cash: 68350.02
# SPY: 132.21846623595943, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-08-02 | Beta Exposure: -2921.48 | Cash: 65380.74
# SPY: 144.21846623595943, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-08-03 | Beta Exposure: -2894.32 | Cash: 62417.22
# SPY: 156.21846623595943, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-08-04 | Beta Exposure: -2896.63 | Cash: 59448.30
# SPY: 168.21846623595943, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-08-07 | Beta Exposure: -2898.11 | Cash: 56473.86
# SPY: 180.21846623595943, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-08-08 | Beta Exposure: -2867.58 | Cash: 53506.74
# SPY: 192.21846623595943, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-08-09 | Beta Exposure: -2851.37 | Cash: 50539.74
# SPY: 204.21846623595943, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-08-10 | Beta Exposure: -2713.03 | Cash: 47614.62
# SPY: 216.21846623595943, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-08-11 | Beta Exposure: -2711.30 | Cash: 44929.30
# SPY: 227.21846623595943, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-08-14 | Beta Exposure: -2786.21 | Cash: 42217.36
# SPY: 238.21846623595943, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-08-15 | Beta Exposure: -2775.21 | Cash: 39505.75
# SPY: 249.21846623595943, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-08-16 | Beta Exposure: -2779.37 | Cash: 36789.41
# SPY: 260.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-08-17 | Beta Exposure: -2626.03 | Cash: 34115.42
# SPY: 271.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-08-18 | Beta Exposure: -2600.71 | Cash: 31445.61
# SPY: 282.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-08-21 | Beta Exposure: -2598.13 | Cash: 28773.71
# SPY: 293.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-08-22 | Beta Exposure: -2672.20 | Cash: 26073.87
# SPY: 304.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-08-23 | Beta Exposure: -2631.72 | Cash: 23383.71
# SPY: 315.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-08-24 | Beta Exposure: -2598.82 | Cash: 20699.82
# SPY: 326.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-08-25 | Beta Exposure: -2605.51 | Cash: 18009.66
# SPY: 337.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-08-28 | Beta Exposure: -2598.72 | Cash: 15319.39
# SPY: 348.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-08-29 | Beta Exposure: -2593.62 | Cash: 12626.04
# SPY: 359.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-08-30 | Beta Exposure: -2628.10 | Cash: 9919.93
# SPY: 370.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-08-31 | Beta Exposure: -2667.63 | Cash: 7197.54
# SPY: 381.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-09-01 | Beta Exposure: -2672.63 | Cash: 4471.30
# SPY: 392.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-09-05 | Beta Exposure: -2595.10 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-09-06 | Beta Exposure: -2622.05 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-09-07 | Beta Exposure: -2622.89 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-09-08 | Beta Exposure: -2608.57 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-09-11 | Beta Exposure: -2702.90 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-09-12 | Beta Exposure: -2735.75 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-09-13 | Beta Exposure: -2741.64 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-09-14 | Beta Exposure: -2738.28 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-09-15 | Beta Exposure: -2748.38 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-09-18 | Beta Exposure: -2766.91 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-09-19 | Beta Exposure: -2776.18 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-09-20 | Beta Exposure: -2782.91 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-09-21 | Beta Exposure: -2755.96 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-09-22 | Beta Exposure: -2755.96 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-09-25 | Beta Exposure: -2738.28 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-09-26 | Beta Exposure: -2742.49 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-09-27 | Beta Exposure: -2775.33 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-09-28 | Beta Exposure: -2787.12 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-09-29 | Beta Exposure: -2816.60 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-10-02 | Beta Exposure: -2861.24 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-10-03 | Beta Exposure: -2883.14 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-10-04 | Beta Exposure: -2892.40 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2017-10-05 | Beta Exposure: -2950.52 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-10-06 | Beta Exposure: -2939.57 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-10-09 | Beta Exposure: -2925.25 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-10-10 | Beta Exposure: -2948.83 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-10-11 | Beta Exposure: -2964.83 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-10-12 | Beta Exposure: -2948.83 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-10-13 | Beta Exposure: -2959.78 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-10-16 | Beta Exposure: -2972.41 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-10-17 | Beta Exposure: -2979.15 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-10-18 | Beta Exposure: -2987.57 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-10-19 | Beta Exposure: -2992.63 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-10-20 | Beta Exposure: -3039.79 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-10-23 | Beta Exposure: -3004.42 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-10-24 | Beta Exposure: -3020.42 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-10-25 | Beta Exposure: -2971.57 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-10-26 | Beta Exposure: -2982.52 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-10-27 | Beta Exposure: -3062.53 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-10-30 | Beta Exposure: -3027.16 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-10-31 | Beta Exposure: -3038.95 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-11-01 | Beta Exposure: -3055.79 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-11-02 | Beta Exposure: -3058.32 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-11-03 | Beta Exposure: -3088.64 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-11-06 | Beta Exposure: -3102.96 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-11-07 | Beta Exposure: -3100.43 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-11-08 | Beta Exposure: -3118.12 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-11-09 | Beta Exposure: -3078.53 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-11-10 | Beta Exposure: -3071.80 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-11-13 | Beta Exposure: -3081.06 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-11-14 | Beta Exposure: -3058.32 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-11-15 | Beta Exposure: -3004.42 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-11-16 | Beta Exposure: -3088.64 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-11-17 | Beta Exposure: -3060.85 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-11-20 | Beta Exposure: -3073.48 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-11-21 | Beta Exposure: -3142.54 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-11-22 | Beta Exposure: -3134.96 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-11-24 | Beta Exposure: -3155.18 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-11-27 | Beta Exposure: -3151.81 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-11-28 | Beta Exposure: -3257.93 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-11-29 | Beta Exposure: -3251.19 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-11-30 | Beta Exposure: -3342.99 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2017-12-01 | Beta Exposure: -3323.62 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2017-12-04 | Beta Exposure: -3310.14 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2017-12-05 | Beta Exposure: -3268.88 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-12-06 | Beta Exposure: -3268.03 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-12-07 | Beta Exposure: -3303.41 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2017-12-08 | Beta Exposure: -3364.05 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2017-12-11 | Beta Exposure: -3398.58 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2017-12-12 | Beta Exposure: -3419.63 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2017-12-13 | Beta Exposure: -3280.67 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-12-14 | Beta Exposure: -3236.03 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-12-15 | Beta Exposure: -3325.30 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-12-18 | Beta Exposure: -3398.58 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2017-12-19 | Beta Exposure: -3346.36 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2017-12-20 | Beta Exposure: -3337.94 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2017-12-21 | Beta Exposure: -3357.31 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2017-12-22 | Beta Exposure: -3353.10 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2017-12-26 | Beta Exposure: -3339.62 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2017-12-27 | Beta Exposure: -3346.36 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2017-12-28 | Beta Exposure: -3364.89 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2017-12-29 | Beta Exposure: -3330.36 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-01-02 | Beta Exposure: -3402.79 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-01-03 | Beta Exposure: -3470.17 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-01-04 | Beta Exposure: -3519.02 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-01-05 | Beta Exposure: -3593.13 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-01-08 | Beta Exposure: -3617.56 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-01-09 | Beta Exposure: -3645.35 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-01-10 | Beta Exposure: -3621.77 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-01-11 | Beta Exposure: -3712.73 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-01-12 | Beta Exposure: -3792.74 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-01-16 | Beta Exposure: -3748.10 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-01-17 | Beta Exposure: -3863.49 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-01-18 | Beta Exposure: -3846.64 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-01-19 | Beta Exposure: -3899.70 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-01-22 | Beta Exposure: -4005.82 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-01-23 | Beta Exposure: -4035.30 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-01-24 | Beta Exposure: -4028.56 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-01-25 | Beta Exposure: -4034.46 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-01-26 | Beta Exposure: -4185.22 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 15 SPY to reduce beta
# 2018-01-29 | Beta Exposure: -4095.10 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-01-30 | Beta Exposure: -3951.92 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-01-31 | Beta Exposure: -3962.87 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-02-01 | Beta Exposure: -3945.18 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-02-02 | Beta Exposure: -3662.19 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-02-05 | Beta Exposure: -3162.76 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-02-06 | Beta Exposure: -3360.68 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-02-07 | Beta Exposure: -3295.83 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-02-08 | Beta Exposure: -2884.82 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-02-09 | Beta Exposure: -3035.58 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-02-12 | Beta Exposure: -3170.34 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-02-13 | Beta Exposure: -3202.34 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-02-14 | Beta Exposure: -3346.36 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-02-15 | Beta Exposure: -3487.01 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-02-16 | Beta Exposure: -3487.85 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-02-20 | Beta Exposure: -3417.95 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-02-21 | Beta Exposure: -3354.78 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-02-22 | Beta Exposure: -3373.31 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-02-23 | Beta Exposure: -3553.55 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-02-26 | Beta Exposure: -3691.67 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-02-27 | Beta Exposure: -3536.70 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-02-28 | Beta Exposure: -3406.16 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-03-01 | Beta Exposure: -3250.35 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-03-02 | Beta Exposure: -3307.62 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-03-05 | Beta Exposure: -3431.43 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-03-06 | Beta Exposure: -3461.75 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-03-07 | Beta Exposure: -3459.22 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-03-08 | Beta Exposure: -3513.96 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-03-09 | Beta Exposure: -3714.41 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-03-12 | Beta Exposure: -3700.09 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-03-13 | Beta Exposure: -3618.40 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-03-14 | Beta Exposure: -3556.92 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-03-15 | Beta Exposure: -3542.60 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-03-16 | Beta Exposure: -3551.86 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-03-19 | Beta Exposure: -3391.00 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-03-20 | Beta Exposure: -3409.53 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-03-21 | Beta Exposure: -3390.16 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-03-22 | Beta Exposure: -3108.01 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-03-23 | Beta Exposure: -2875.56 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-03-26 | Beta Exposure: -3150.12 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-03-27 | Beta Exposure: -2958.94 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-03-28 | Beta Exposure: -2935.36 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-03-29 | Beta Exposure: -3074.32 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-04-02 | Beta Exposure: -2832.60 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-04-03 | Beta Exposure: -2959.78 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-04-04 | Beta Exposure: -3068.43 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-04-05 | Beta Exposure: -3142.54 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-04-06 | Beta Exposure: -2910.09 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-04-09 | Beta Exposure: -2947.99 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-04-10 | Beta Exposure: -3116.43 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-04-11 | Beta Exposure: -3055.79 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-04-12 | Beta Exposure: -3143.38 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-04-13 | Beta Exposure: -3111.38 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-04-16 | Beta Exposure: -3195.60 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-04-17 | Beta Exposure: -3310.14 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-04-18 | Beta Exposure: -3316.88 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-04-19 | Beta Exposure: -3256.24 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-04-20 | Beta Exposure: -3161.07 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-04-23 | Beta Exposure: -3158.54 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-04-24 | Beta Exposure: -3019.58 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-04-25 | Beta Exposure: -3038.95 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-04-26 | Beta Exposure: -3142.54 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-04-27 | Beta Exposure: -3150.96 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-04-30 | Beta Exposure: -3068.43 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-05-01 | Beta Exposure: -3086.96 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-05-02 | Beta Exposure: -3012.84 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-05-03 | Beta Exposure: -2990.94 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-05-04 | Beta Exposure: -3121.49 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-05-07 | Beta Exposure: -3155.18 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-05-08 | Beta Exposure: -3156.02 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-05-09 | Beta Exposure: -3257.93 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-05-10 | Beta Exposure: -3363.21 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-05-11 | Beta Exposure: -3384.26 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-05-14 | Beta Exposure: -3396.05 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-05-15 | Beta Exposure: -3320.25 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-05-16 | Beta Exposure: -3369.10 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-05-17 | Beta Exposure: -3357.31 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-05-18 | Beta Exposure: -3328.67 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-05-21 | Beta Exposure: -3410.37 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-05-22 | Beta Exposure: -3378.37 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-05-23 | Beta Exposure: -3410.37 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-05-24 | Beta Exposure: -3388.47 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-05-25 | Beta Exposure: -3357.31 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-05-29 | Beta Exposure: -3230.98 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-05-30 | Beta Exposure: -3371.63 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-05-31 | Beta Exposure: -3294.14 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-06-01 | Beta Exposure: -3409.53 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-06-04 | Beta Exposure: -3463.43 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-06-05 | Beta Exposure: -3471.85 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-06-06 | Beta Exposure: -3569.55 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-06-07 | Beta Exposure: -3562.81 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-06-08 | Beta Exposure: -3596.50 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-06-11 | Beta Exposure: -3614.19 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-06-12 | Beta Exposure: -3633.56 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-06-13 | Beta Exposure: -3587.24 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-06-14 | Beta Exposure: -3618.40 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-06-15 | Beta Exposure: -3602.40 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-06-18 | Beta Exposure: -3574.60 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-06-19 | Beta Exposure: -3529.12 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-06-20 | Beta Exposure: -3551.86 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-06-21 | Beta Exposure: -3475.22 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-06-22 | Beta Exposure: -3492.07 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-06-25 | Beta Exposure: -3336.25 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-06-26 | Beta Exposure: -3357.31 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-06-27 | Beta Exposure: -3262.14 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-06-28 | Beta Exposure: -3331.20 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-06-29 | Beta Exposure: -3348.05 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-07-02 | Beta Exposure: -3358.99 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-07-03 | Beta Exposure: -3316.88 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-07-05 | Beta Exposure: -3408.68 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-07-06 | Beta Exposure: -3502.17 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-07-09 | Beta Exposure: -3612.50 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-07-10 | Beta Exposure: -3651.25 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-07-11 | Beta Exposure: -3569.55 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-07-12 | Beta Exposure: -3669.77 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-07-13 | Beta Exposure: -3677.35 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-07-16 | Beta Exposure: -3668.93 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-07-17 | Beta Exposure: -3717.78 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-07-18 | Beta Exposure: -3742.21 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-07-19 | Beta Exposure: -3693.36 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-07-20 | Beta Exposure: -3682.41 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-07-23 | Beta Exposure: -3704.31 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-07-24 | Beta Exposure: -3758.21 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-07-25 | Beta Exposure: -3873.59 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-07-26 | Beta Exposure: -3835.69 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-07-27 | Beta Exposure: -3751.47 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-07-30 | Beta Exposure: -3679.88 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-07-31 | Beta Exposure: -3739.68 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-08-01 | Beta Exposure: -3726.20 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-08-02 | Beta Exposure: -3785.16 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-08-03 | Beta Exposure: -3842.43 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-08-06 | Beta Exposure: -3888.75 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-08-07 | Beta Exposure: -3929.18 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-08-08 | Beta Exposure: -3924.13 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-08-09 | Beta Exposure: -3905.60 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-08-10 | Beta Exposure: -3816.32 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-08-13 | Beta Exposure: -3767.47 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-08-14 | Beta Exposure: -3845.80 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-08-15 | Beta Exposure: -3754.00 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-08-16 | Beta Exposure: -3850.85 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-08-17 | Beta Exposure: -3892.12 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-08-20 | Beta Exposure: -3920.76 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-08-21 | Beta Exposure: -3947.71 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-08-22 | Beta Exposure: -3943.50 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-08-23 | Beta Exposure: -3923.28 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-08-24 | Beta Exposure: -3997.40 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-08-27 | Beta Exposure: -4100.99 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-08-28 | Beta Exposure: -4113.63 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-08-29 | Beta Exposure: -4182.69 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-08-30 | Beta Exposure: -4123.73 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-08-31 | Beta Exposure: -4123.73 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-09-04 | Beta Exposure: -4102.68 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-09-05 | Beta Exposure: -4068.15 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-09-06 | Beta Exposure: -4026.88 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-09-07 | Beta Exposure: -3992.35 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-09-10 | Beta Exposure: -4017.61 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-09-11 | Beta Exposure: -4064.78 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-09-12 | Beta Exposure: -4066.46 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-09-13 | Beta Exposure: -4139.73 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-09-14 | Beta Exposure: -4141.42 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-09-17 | Beta Exposure: -4068.15 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-09-18 | Beta Exposure: -4138.05 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-09-19 | Beta Exposure: -4154.89 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-09-20 | Beta Exposure: -4261.02 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 15 SPY to reduce beta
# 2018-09-21 | Beta Exposure: -4250.07 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 15 SPY to reduce beta
# 2018-09-24 | Beta Exposure: -4206.27 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-09-25 | Beta Exposure: -4179.32 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-09-26 | Beta Exposure: -4136.37 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-09-27 | Beta Exposure: -4173.42 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-09-28 | Beta Exposure: -4171.74 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-10-01 | Beta Exposure: -4219.75 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-10-02 | Beta Exposure: -4212.17 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-10-03 | Beta Exposure: -4222.27 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-10-04 | Beta Exposure: -4111.94 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-10-05 | Beta Exposure: -4042.88 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-10-08 | Beta Exposure: -4031.93 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-10-09 | Beta Exposure: -4015.09 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 14 SPY to reduce beta
# 2018-10-10 | Beta Exposure: -3596.50 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-10-11 | Beta Exposure: -3325.30 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-10-12 | Beta Exposure: -3485.33 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-10-15 | Beta Exposure: -3416.26 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-10-16 | Beta Exposure: -3657.98 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-10-17 | Beta Exposure: -3663.04 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-10-18 | Beta Exposure: -3492.07 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-10-19 | Beta Exposure: -3476.06 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-10-22 | Beta Exposure: -3430.58 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-10-23 | Beta Exposure: -3364.89 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-10-24 | Beta Exposure: -3023.79 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-10-25 | Beta Exposure: -3211.60 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-10-26 | Beta Exposure: -3012.84 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-10-29 | Beta Exposure: -2954.73 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-10-30 | Beta Exposure: -3110.54 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-10-31 | Beta Exposure: -3219.18 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-11-01 | Beta Exposure: -3335.41 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-11-02 | Beta Exposure: -3258.77 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-11-05 | Beta Exposure: -3322.78 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-11-06 | Beta Exposure: -3393.53 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-11-07 | Beta Exposure: -3630.19 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-11-08 | Beta Exposure: -3610.82 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-11-09 | Beta Exposure: -3498.80 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-11-12 | Beta Exposure: -3272.24 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-11-13 | Beta Exposure: -3252.03 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-11-14 | Beta Exposure: -3177.92 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-11-15 | Beta Exposure: -3291.62 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-11-16 | Beta Exposure: -3312.67 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-11-19 | Beta Exposure: -3140.86 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-11-20 | Beta Exposure: -2934.51 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-11-21 | Beta Exposure: -2966.52 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-11-23 | Beta Exposure: -2898.30 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-11-26 | Beta Exposure: -3049.90 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-11-27 | Beta Exposure: -3083.59 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-11-28 | Beta Exposure: -3325.30 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-11-29 | Beta Exposure: -3300.04 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-11-30 | Beta Exposure: -3375.00 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-12-03 | Beta Exposure: -3513.12 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 13 SPY to reduce beta
# 2018-12-04 | Beta Exposure: -3142.54 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-12-06 | Beta Exposure: -3122.33 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 12 SPY to reduce beta
# 2018-12-07 | Beta Exposure: -2872.19 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-12-10 | Beta Exposure: -2888.19 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-12-11 | Beta Exposure: -2889.03 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-12-12 | Beta Exposure: -2939.57 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-12-13 | Beta Exposure: -2932.83 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# → Buying 11 SPY to reduce beta
# 2018-12-14 | Beta Exposure: -2750.07 | Cash: 1764.64
# SPY: 403.21846623595945, SPXL: -28.07411650719794
# ...
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 25 SPY to reduce beta
# 2025-01-27 | Beta Exposure: -14599.20 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 24 SPY to reduce beta
# 2025-01-28 | Beta Exposure: -14963.05 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 25 SPY to reduce beta
# 2025-01-29 | Beta Exposure: -14770.18 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 25 SPY to reduce beta
# 2025-01-30 | Beta Exposure: -15006.00 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 25 SPY to reduce beta
# 2025-01-31 | Beta Exposure: -14749.12 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 25 SPY to reduce beta
# 2025-02-03 | Beta Exposure: -14426.55 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 24 SPY to reduce beta
# 2025-02-04 | Beta Exposure: -14711.22 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 24 SPY to reduce beta
# 2025-02-05 | Beta Exposure: -14904.09 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 25 SPY to reduce beta
# 2025-02-06 | Beta Exposure: -15059.90 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 25 SPY to reduce beta
# 2025-02-07 | Beta Exposure: -14623.63 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 24 SPY to reduce beta
# 2025-02-10 | Beta Exposure: -14914.20 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 25 SPY to reduce beta
# 2025-02-11 | Beta Exposure: -14946.20 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 25 SPY to reduce beta
# 2025-02-12 | Beta Exposure: -14806.39 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 25 SPY to reduce beta
# 2025-02-13 | Beta Exposure: -15267.93 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 25 SPY to reduce beta
# 2025-02-14 | Beta Exposure: -15253.61 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 25 SPY to reduce beta
# 2025-02-18 | Beta Exposure: -15374.89 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 25 SPY to reduce beta
# 2025-02-19 | Beta Exposure: -15487.75 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 25 SPY to reduce beta
# 2025-02-20 | Beta Exposure: -15283.09 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 25 SPY to reduce beta
# 2025-02-21 | Beta Exposure: -14477.92 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 24 SPY to reduce beta
# 2025-02-24 | Beta Exposure: -14261.47 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 24 SPY to reduce beta
# 2025-02-25 | Beta Exposure: -14034.91 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 24 SPY to reduce beta
# 2025-02-26 | Beta Exposure: -14045.86 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 24 SPY to reduce beta
# 2025-02-27 | Beta Exposure: -13365.35 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 23 SPY to reduce beta
# 2025-02-28 | Beta Exposure: -13981.85 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 24 SPY to reduce beta
# 2025-03-03 | Beta Exposure: -13234.80 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 23 SPY to reduce beta
# 2025-03-04 | Beta Exposure: -12747.16 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 22 SPY to reduce beta
# 2025-03-05 | Beta Exposure: -13108.47 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 22 SPY to reduce beta
# 2025-03-06 | Beta Exposure: -12438.06 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 22 SPY to reduce beta
# 2025-03-07 | Beta Exposure: -12619.98 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 22 SPY to reduce beta
# 2025-03-10 | Beta Exposure: -11592.47 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-03-11 | Beta Exposure: -11280.84 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 20 SPY to reduce beta
# 2025-03-12 | Beta Exposure: -11454.34 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 20 SPY to reduce beta
# 2025-03-13 | Beta Exposure: -10989.43 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 20 SPY to reduce beta
# 2025-03-14 | Beta Exposure: -11668.27 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-03-17 | Beta Exposure: -11932.72 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-03-18 | Beta Exposure: -11557.93 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-03-19 | Beta Exposure: -11922.62 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-03-20 | Beta Exposure: -11836.71 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-03-21 | Beta Exposure: -11829.97 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-03-24 | Beta Exposure: -12470.06 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 22 SPY to reduce beta
# 2025-03-25 | Beta Exposure: -12520.60 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 22 SPY to reduce beta
# 2025-03-26 | Beta Exposure: -12069.17 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-03-27 | Beta Exposure: -11954.62 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-03-28 | Beta Exposure: -11207.57 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 20 SPY to reduce beta
# 2025-03-31 | Beta Exposure: -11414.76 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 20 SPY to reduce beta
# 2025-04-01 | Beta Exposure: -11525.93 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-04-02 | Beta Exposure: -11748.28 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-04-03 | Beta Exposure: -10019.19 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 19 SPY to reduce beta
# 2025-04-04 | Beta Exposure: -8139.35 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 16 SPY to reduce beta
# 2025-04-07 | Beta Exposure: -8076.18 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 16 SPY to reduce beta
# 2025-04-08 | Beta Exposure: -7685.39 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 15 SPY to reduce beta
# 2025-04-09 | Beta Exposure: -9916.44 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 18 SPY to reduce beta
# 2025-04-10 | Beta Exposure: -8862.82 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 17 SPY to reduce beta
# 2025-04-11 | Beta Exposure: -9338.68 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 17 SPY to reduce beta
# 2025-04-14 | Beta Exposure: -9625.03 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 18 SPY to reduce beta
# 2025-04-15 | Beta Exposure: -9553.44 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 18 SPY to reduce beta
# 2025-04-16 | Beta Exposure: -8888.09 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 17 SPY to reduce beta
# 2025-04-17 | Beta Exposure: -8909.14 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 17 SPY to reduce beta
# 2025-04-21 | Beta Exposure: -8245.47 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 16 SPY to reduce beta
# 2025-04-22 | Beta Exposure: -8891.46 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 17 SPY to reduce beta
# 2025-04-23 | Beta Exposure: -9347.10 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 17 SPY to reduce beta
# 2025-04-24 | Beta Exposure: -9950.97 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 18 SPY to reduce beta
# 2025-04-25 | Beta Exposure: -10170.79 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 18 SPY to reduce beta
# 2025-04-28 | Beta Exposure: -10187.64 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 18 SPY to reduce beta
# 2025-04-29 | Beta Exposure: -10372.08 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 19 SPY to reduce beta
# 2025-04-30 | Beta Exposure: -10378.82 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 19 SPY to reduce beta
# 2025-05-01 | Beta Exposure: -10607.07 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 19 SPY to reduce beta
# 2025-05-02 | Beta Exposure: -11091.34 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 20 SPY to reduce beta
# 2025-05-05 | Beta Exposure: -10895.95 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 19 SPY to reduce beta
# 2025-05-06 | Beta Exposure: -10614.64 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 19 SPY to reduce beta
# 2025-05-07 | Beta Exposure: -10750.24 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 19 SPY to reduce beta
# 2025-05-08 | Beta Exposure: -10977.64 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 19 SPY to reduce beta
# 2025-05-09 | Beta Exposure: -10920.37 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 19 SPY to reduce beta
# 2025-05-12 | Beta Exposure: -12032.95 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-05-13 | Beta Exposure: -12278.88 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-05-14 | Beta Exposure: -12325.20 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-05-15 | Beta Exposure: -12504.59 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-05-16 | Beta Exposure: -12750.52 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-05-19 | Beta Exposure: -12786.74 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-05-20 | Beta Exposure: -12639.35 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-05-21 | Beta Exposure: -11990.00 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-05-22 | Beta Exposure: -11984.10 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-05-23 | Beta Exposure: -11731.43 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 20 SPY to reduce beta
# 2025-05-27 | Beta Exposure: -12478.49 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-05-28 | Beta Exposure: -12239.29 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-05-29 | Beta Exposure: -12411.11 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-05-30 | Beta Exposure: -12345.41 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-06-02 | Beta Exposure: -12557.66 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-06-03 | Beta Exposure: -12780.84 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-06-04 | Beta Exposure: -12754.74 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-06-05 | Beta Exposure: -12565.23 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-06-06 | Beta Exposure: -12945.92 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 22 SPY to reduce beta
# 2025-06-09 | Beta Exposure: -12981.29 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 22 SPY to reduce beta
# 2025-06-10 | Beta Exposure: -13207.01 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 22 SPY to reduce beta
# 2025-06-11 | Beta Exposure: -13094.15 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 22 SPY to reduce beta
# 2025-06-12 | Beta Exposure: -13237.33 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 22 SPY to reduce beta
# 2025-06-13 | Beta Exposure: -12776.63 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-06-16 | Beta Exposure: -13153.11 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 22 SPY to reduce beta
# 2025-06-17 | Beta Exposure: -12799.37 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-06-18 | Beta Exposure: -12782.53 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-06-20 | Beta Exposure: -12651.14 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 21 SPY to reduce beta
# 2025-06-23 | Beta Exposure: -13063.83 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 22 SPY to reduce beta
# 2025-06-24 | Beta Exposure: -13442.83 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 22 SPY to reduce beta
# 2025-06-25 | Beta Exposure: -13466.41 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 22 SPY to reduce beta
# 2025-06-26 | Beta Exposure: -13797.41 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 23 SPY to reduce beta
# 2025-06-27 | Beta Exposure: -13986.91 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 23 SPY to reduce beta
# 2025-06-30 | Beta Exposure: -14205.89 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 23 SPY to reduce beta
# 2025-07-01 | Beta Exposure: -14180.62 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 23 SPY to reduce beta
# 2025-07-02 | Beta Exposure: -14365.91 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 23 SPY to reduce beta
# 2025-07-03 | Beta Exposure: -14701.11 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 24 SPY to reduce beta
# 2025-07-07 | Beta Exposure: -14364.22 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 23 SPY to reduce beta
# 2025-07-08 | Beta Exposure: -14335.59 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 23 SPY to reduce beta
# 2025-07-09 | Beta Exposure: -14592.47 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 23 SPY to reduce beta
# 2025-07-10 | Beta Exposure: -14720.48 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 24 SPY to reduce beta
# 2025-07-11 | Beta Exposure: -14543.62 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 23 SPY to reduce beta
# 2025-07-14 | Beta Exposure: -14623.63 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 23 SPY to reduce beta
# 2025-07-15 | Beta Exposure: -14429.07 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 23 SPY to reduce beta
# 2025-07-16 | Beta Exposure: -14570.57 | Cash: 247.84
# SPY: 409.21846623595945, SPXL: -28.07411650719794
# → Buying 23 SPY to reduce beta
# <div id='b5ccf263-63aa-42e5-a1c1-6189ac10f20c'></div>
# <div id='a4ba5d43-0410-4797-bb03-0302a740a7d5'></div>
